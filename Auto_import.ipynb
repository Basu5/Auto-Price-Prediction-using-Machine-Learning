# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("auto_imports.csv")
data
# Out:
#      symboling normalized_losses         make fuel_type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo       gas      turbo
# 198         -1                95        volvo       gas        std
# 199         -1                95        volvo    diesel      turbo
# 200         -1                95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
data.shape
# Out:
# (201, 26)

# %%
data.head()
# Out:
#    symboling normalized_losses         make fuel_type aspiration num_of_doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.tail()
# Out:
#      symboling normalized_losses   make fuel_type aspiration num_of_doors  \
# 196         -1                95  volvo       gas        std         four
# 197         -1                95  volvo       gas      turbo         four
# 198         -1                95  volvo       gas        std         four
# 199         -1                95  volvo    diesel      turbo         four
# 200         -1                95  volvo       gas      turbo         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# ...

# %%
data.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'num_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
 # pd.set_option('display.max_columns',None)
 # data.head()

# %%
data.dtypes
# Out:
# symboling              int64
# normalized_losses     object
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors          object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders      object
# engine_size            int64
# fuel_system           object
# bore                  object
# stroke                object
# compression_ratio    float64
# horsepower            object
# peak_rpm              object
# city_mpg               int64
# highway_mpg            int64
# price                  int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized_losses  201 non-null    object
#  2   make               201 non-null    object
#  3   fuel_type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num_of_doors       201 non-null    object
#  6   body_style         201 non-null    object
#  7   drive_wheels       201 non-null    object
#  8   engine_location    201 non-null    object
#  9   wheel_base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb_weight        201 non-null    int64
#  14  engine_type        201 non-null    object
#  15  num_of_cylinders   201 non-null    object
# ...

# %%
data.describe()
# Out:
#         symboling  wheel_base      length       width      height  \
# count  201.000000  201.000000  201.000000  201.000000  201.000000
# mean     0.840796   98.797015  174.200995   65.889055   53.766667
# std      1.254802    6.066366   12.322175    2.101471    2.447822
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.800000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.500000   66.600000   55.500000
# max      3.000000  120.900000  208.100000   72.000000   59.800000
#
#        curb_weight  engine_size  compression_ratio    city_mpg  highway_mpg  \
# count   201.000000   201.000000         201.000000  201.000000   201.000000
# mean   2555.666667   126.875622          10.164279   25.179104    30.686567
# std     517.296727    41.546834           4.004965    6.423220     6.815150
# ...

# %%
data.describe(include='object')
# Out:
#        normalized_losses    make fuel_type aspiration num_of_doors body_style  \
# count                201     201       201        201          201        201
# unique                52      22         2          2            3          5
# top                    ?  toyota       gas        std         four      sedan
# freq                  37      32       181        165          113         94
#
#        drive_wheels engine_location engine_type num_of_cylinders fuel_system  \
# count           201             201         201              201         201
# unique            3               2           6                7           8
# top             fwd           front         ohc             four        mpfi
# freq            118             198         145              157          92
#
#         bore stroke horsepower peak_rpm
# count    201    201        201      201
# unique    39     37         59       23
# top     3.62    3.4         68     5500
# ...

# %%
len(data.loc[data['normalized_losses']== '?'])
# Out:
# 37

# %%
data['normalized_losses'] = pd.to_numeric(data['normalized_losses'], errors='coerce')

# %%
data['normalized_losses'].unique()
# Out:
# array([ nan, 164., 158., 192., 188., 121.,  98.,  81., 118., 148., 110.,
#        145., 137., 101.,  78., 106.,  85., 107., 104., 113., 150., 129.,
#        115.,  93., 142., 161., 153., 125., 128., 122., 103., 168., 108.,
#        194., 231., 119., 154.,  74., 186.,  83., 102.,  89.,  87.,  77.,
#         91., 134.,  65., 197.,  90.,  94., 256.,  95.])

# %%
data.loc[data['normalized_losses'].isnull()]
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 0            3                NaN    alfa-romero       gas        std
# 1            3                NaN    alfa-romero       gas        std
# 2            1                NaN    alfa-romero       gas        std
# 5            2                NaN           audi       gas        std
# 7            1                NaN           audi       gas        std
# 13           1                NaN            bmw       gas        std
# 14           0                NaN            bmw       gas        std
# 15           0                NaN            bmw       gas        std
# 16           0                NaN            bmw       gas        std
# 42           0                NaN          isuzu       gas        std
# 43           2                NaN          isuzu       gas        std
# 45           0                NaN         jaguar       gas        std
# ...

# %%
sns.distplot(x=data['normalized_losses'])
# Out:
# <Axes: ylabel='Density'>

# %%
data.loc[data['normalized_losses'].isnull(),'normalized_losses']=data['normalized_losses'].median()

# %%
data.loc[data['bore']=='?']
# Out:
#     symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 52          3              150.0  mazda       gas        std          two
# 53          3              150.0  mazda       gas        std          two
# 54          3              150.0  mazda       gas        std          two
# 55          3              150.0  mazda       gas        std          two
#
#    body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 52  hatchback          rwd           front        95.3  ...           70
# 53  hatchback          rwd           front        95.3  ...           70
# 54  hatchback          rwd           front        95.3  ...           70
# 55  hatchback          rwd           front        95.3  ...           80
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 52         4bbl     ?       ?               9.4        101      6000       17
# ...

# %%
data['bore'] = pd.to_numeric(data['bore'], errors='coerce')

# %%
data.loc[data['bore'].isnull()]
# Out:
#     symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 52          3              150.0  mazda       gas        std          two
# 53          3              150.0  mazda       gas        std          two
# 54          3              150.0  mazda       gas        std          two
# 55          3              150.0  mazda       gas        std          two
#
#    body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 52  hatchback          rwd           front        95.3  ...           70
# 53  hatchback          rwd           front        95.3  ...           70
# 54  hatchback          rwd           front        95.3  ...           70
# 55  hatchback          rwd           front        95.3  ...           80
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 52         4bbl   NaN       ?               9.4        101      6000       17
# ...

# %%
sns.distplot(x=data['bore'])
# Out:
# <Axes: ylabel='Density'>

# %%
data.loc[data['bore'].isnull(),'bore']=data['bore'].median()

# %%
data.loc[data['stroke']=='?']
# Out:
#     symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 52          3              150.0  mazda       gas        std          two
# 53          3              150.0  mazda       gas        std          two
# 54          3              150.0  mazda       gas        std          two
# 55          3              150.0  mazda       gas        std          two
#
#    body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 52  hatchback          rwd           front        95.3  ...           70
# 53  hatchback          rwd           front        95.3  ...           70
# 54  hatchback          rwd           front        95.3  ...           70
# 55  hatchback          rwd           front        95.3  ...           80
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 52         4bbl  3.31       ?               9.4        101      6000       17
# ...

# %%
len(data.loc[data['stroke']=='?'])
# Out:
# 4

# %%
data['stroke']=pd.to_numeric(data['stroke'],errors='coerce')

# %%
data.loc[data['stroke'].isnull()]
# Out:
#     symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 52          3              150.0  mazda       gas        std          two
# 53          3              150.0  mazda       gas        std          two
# 54          3              150.0  mazda       gas        std          two
# 55          3              150.0  mazda       gas        std          two
#
#    body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 52  hatchback          rwd           front        95.3  ...           70
# 53  hatchback          rwd           front        95.3  ...           70
# 54  hatchback          rwd           front        95.3  ...           70
# 55  hatchback          rwd           front        95.3  ...           80
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 52         4bbl  3.31     NaN               9.4        101      6000       17
# ...

# %%
sns.distplot(x=data['stroke'])
# Out:
# <Axes: ylabel='Density'>

# %%
data.loc[data['stroke'].isnull(),'stroke']=data['stroke'].median()

# %%
print(data['horsepower'].unique())
print(len(data['horsepower'].unique()))
# Out:
# ['111' '154' '102' '115' '110' '140' '101' '121' '182' '48' '70' '68' '88'
#  '145' '58' '76' '60' '86' '100' '78' '90' '176' '262' '135' '84' '64'
#  '120' '72' '123' '155' '184' '175' '116' '69' '55' '97' '152' '160' '200'
#  '95' '142' '143' '207' '?' '73' '82' '94' '62' '56' '112' '92' '161'
#  '156' '52' '85' '114' '162' '134' '106']
# 59

# %%
print(data['peak_rpm'].unique())
print(len(data['peak_rpm'].unique()))
# Out:
# ['5000' '5500' '5800' '4250' '5400' '5100' '4800' '6000' '4750' '4650'
#  '4200' '4350' '4500' '5200' '4150' '5600' '5900' '?' '5250' '4900' '4400'
#  '6600' '5300']
# 23

# %%
data.loc[data['bore'].isnull(),'bore']=data['bore'].median()

# %%
data.dtypes
# Out:
# symboling              int64
# normalized_losses    float64
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors          object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders      object
# engine_size            int64
# fuel_system           object
# bore                 float64
# stroke               float64
# compression_ratio    float64
# horsepower            object
# peak_rpm              object
# city_mpg               int64
# highway_mpg            int64
# price                  int64
# dtype: object

# %%
data.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3              115.0  alfa-romero       gas        std
# 1          3              115.0  alfa-romero       gas        std
# 2          1              115.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
data.loc[data['horsepower']=='?']
# Out:
#      symboling  normalized_losses     make fuel_type aspiration num_of_doors  \
# 126          0              115.0  renault       gas        std         four
# 127          2              115.0  renault       gas        std          two
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 126      wagon          fwd           front        96.1  ...          132
# 127  hatchback          fwd           front        96.1  ...          132
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 126         mpfi  3.46     3.9               8.7          ?         ?
# 127         mpfi  3.46     3.9               8.7          ?         ?
#
#     city_mpg  highway_mpg  price
# 126       23           31   9295
# 127       23           31   9895
#
# [2 rows x 26 columns]

# %%
data['horsepower']=pd.to_numeric(data['horsepower'],errors='coerce')

# %%
sns.distplot(x=data['horsepower'])
# Out:
# <Axes: ylabel='Density'>

# %%
data.loc[data['horsepower'].isnull(),'horsepower']=data['horsepower'].median()

# %%
data.loc[data['peak_rpm']=='?']
# Out:
#      symboling  normalized_losses     make fuel_type aspiration num_of_doors  \
# 126          0              115.0  renault       gas        std         four
# 127          2              115.0  renault       gas        std          two
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 126      wagon          fwd           front        96.1  ...          132
# 127  hatchback          fwd           front        96.1  ...          132
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 126         mpfi  3.46     3.9               8.7       95.0         ?
# 127         mpfi  3.46     3.9               8.7       95.0         ?
#
#     city_mpg  highway_mpg  price
# 126       23           31   9295
# 127       23           31   9895
#
# [2 rows x 26 columns]

# %%
data['peak_rpm']=pd.to_numeric(data['peak_rpm'],errors='coerce')

# %%
sns.distplot(x=data['peak_rpm'])
# Out:
# <Axes: ylabel='Density'>

# %%
data.loc[data['peak_rpm'].isnull(),'peak_rpm']=data['peak_rpm'].median()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized_losses  201 non-null    float64
#  2   make               201 non-null    object
#  3   fuel_type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num_of_doors       201 non-null    object
#  6   body_style         201 non-null    object
#  7   drive_wheels       201 non-null    object
#  8   engine_location    201 non-null    object
#  9   wheel_base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb_weight        201 non-null    int64
#  14  engine_type        201 non-null    object
#  15  num_of_cylinders   201 non-null    object
# ...

# %%
data.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3              115.0  alfa-romero       gas        std
# 1          3              115.0  alfa-romero       gas        std
# 2          1              115.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
data.describe()
# Out:
#         symboling  normalized_losses  wheel_base      length       width  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000
# mean     0.840796         120.711443   98.797015  174.200995   65.889055
# std      1.254802          32.111623    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  engine_size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.330299    3.257562
# std      2.447822   517.296727    41.546834    0.268088    0.316082
# ...

# %%
data.describe(include='object')
# Out:
#           make fuel_type aspiration num_of_doors body_style drive_wheels  \
# count      201       201        201          201        201          201
# unique      22         2          2            3          5            3
# top     toyota       gas        std         four      sedan          fwd
# freq        32       181        165          113         94          118
#
#        engine_location engine_type num_of_cylinders fuel_system
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92

# %%
data.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(x=data['symboling'])
# Out:
# <Axes: xlabel='symboling'>

# %%
plot=1
plt.figure(figsize=(12,40))
for i in data.select_dtypes(include='number').columns:
    if plot<=16:
        ax=plt.subplot(8,2,plot)
        sns.boxplot(x=data[i])
        plt.xlabel(i)
    plot+=1
plt.tight_layout()

# %%
plot=1
plt.figure(figsize=(12,50))
for i in data.select_dtypes(include='number').columns:
    if plot<=16:
        ax=plt.subplot(8,2,plot)
        sns.distplot(x=data[i])
        plt.xlabel(i)
    plot+=1
plt.tight_layout()

# %%
from sklearn.preprocessing import PowerTransformer

# Step 1: Select numerical columns
num_cols = data.select_dtypes(include='number').columns.drop('symboling')

# Step 3: Apply Box-Cox transformer
boxcox = PowerTransformer(method='box-cox')  # method can be 'box-cox' or 'yeo-johnson'
data_boxcox = data.copy()
data_boxcox[num_cols] = boxcox.fit_transform(data[num_cols])

# %%
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    plt.figure(figsize=(12, 50))
    plot = 1
    for col in num_cols:
        if plot <= 16:
            ax = plt.subplot(8, 2, plot)
            sns.histplot(data_boxcox[col], kde=True)
            plt.xlabel(col)
            plot += 1
    
    plt.tight_layout()
    plt.show()

# %%
#  pd.set_option('display.max_rows',None)
data
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3              115.0  alfa-romero       gas        std
# 1            3              115.0  alfa-romero       gas        std
# 2            1              115.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1               95.0        volvo       gas        std
# 197         -1               95.0        volvo       gas      turbo
# 198         -1               95.0        volvo       gas        std
# 199         -1               95.0        volvo    diesel      turbo
# 200         -1               95.0        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# ...

# %% [markdown]
# ### Outliers Handling

# %%
q1=data['normalized_losses'].quantile(0.25)
q1
# Out:
# 101.0

# %%
q3=data['normalized_losses'].quantile(0.75)
q3
# Out:
# 134.0

# %%
iqr=q3-q1
iqr
# Out:
# 33.0

# %%
lb=q1-1.5*iqr
lb
# Out:
# 51.5

# %%
ub=q3+1.5*iqr
ub
# Out:
# 183.5

# %%
data.loc[data['normalized_losses']<lb]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data['normalized_losses']>ub]
# Out:
#      symboling  normalized_losses     make fuel_type aspiration num_of_doors  \
# 11           0              188.0      bmw       gas        std          two
# 12           0              188.0      bmw       gas        std         four
# 122          3              186.0  porsche       gas        std          two
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 11       sedan          rwd           front       101.2  ...          164
# 12       sedan          rwd           front       101.2  ...          164
# 122  hatchback          rwd           front        94.5  ...          151
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 11          mpfi  3.31    3.19               9.0      121.0    4250.0
# 12          mpfi  3.31    3.19               9.0      121.0    4250.0
# 122         mpfi  3.94    3.11               9.5      143.0    5500.0
#
#     city_mpg  highway_mpg  price
# 11        21           28  20970
# ...

# %%
(len(data.loc[data['normalized_losses']>ub])/len(data))*100
# Out:
# 1.4925373134328357

# %%
data.loc[data['normalized_losses']>ub,'normalized_losses'] = data['normalized_losses'].median()

# %%
sns.boxplot(x=data['normalized_losses'])
# Out:
# <Axes: xlabel='normalized_losses'>

# %%
q1=data['wheel_base'].quantile(0.25)
q1
# Out:
# 94.5

# %%
q3=data['wheel_base'].quantile(0.75)
q3
# Out:
# 101.2

# %%
iqr=q3-q1
iqr
# Out:
# 6.700000000000003

# %%
lb=q1-1.5*iqr
lb
# Out:
# 84.44999999999999

# %%
ub=q3+1.5*iqr
ub
# Out:
# 111.25

# %%
data.loc[data['wheel_base']<lb]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data['wheel_base']>ub]
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 44           0              145.0         jaguar       gas        std
# 45           0              115.0         jaguar       gas        std
# 71           1              115.0  mercedes-benz       gas        std
# 106          0              115.0         peugot       gas        std
# 107          0              115.0         peugot    diesel      turbo
# 110          0              115.0         peugot       gas        std
# 111          0              115.0         peugot    diesel      turbo
#
#     num_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 44          four      sedan          rwd           front       113.0  ...
# 45          four      sedan          rwd           front       113.0  ...
# 71           two    hardtop          rwd           front       112.0  ...
# 106         four      wagon          rwd           front       114.2  ...
# ...

# %%
data.loc[data['wheel_base']>ub,'wheel_base'] = data['wheel_base'].median()

# %%
sns.boxplot(x=data['wheel_base'])
# Out:
# <Axes: xlabel='wheel_base'>

# %%
q1=data['length'].quantile(0.25)
q1
# Out:
# 166.8

# %%
q3=data['length'].quantile(0.75)
q3
# Out:
# 183.5

# %%
iqr=q3-q1
iqr
# Out:
# 16.69999999999999

# %%
lb=q1-1.5*iqr
lb
# Out:
# 141.75000000000003

# %%
ub=q3+1.5*iqr
ub
# Out:
# 208.54999999999998

# %%
data.loc[data['length']<lb]
# Out:
#     symboling  normalized_losses       make fuel_type aspiration num_of_doors  \
# 17          2              121.0  chevrolet       gas        std          two
#
#    body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 17  hatchback          fwd           front        88.4  ...           61
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 17         2bbl  2.91    3.03               9.5       48.0    5100.0       47
#
#     highway_mpg  price
# 17           53   5151
#
# [1 rows x 26 columns]

# %%
data.loc[data['length']>ub]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data['length']<lb,'length'] = data['length'].median()

# %%
sns.boxplot(x=data['length'])
# Out:
# <Axes: xlabel='length'>

# %%
q1=data['width'].quantile(0.25)
q1
# Out:
# 64.2

# %%
q3=data["width"].quantile(0.75)
q3
# Out:
# 66.5

# %%
iqr=q3-q1
iqr
# Out:
# 2.299999999999997

# %%
lower=q1-1.5*iqr
lower
# Out:
# 60.75000000000001

# %%
upper=q3+1.5*iqr
upper
# Out:
# 69.94999999999999

# %%
data.loc[data["width"]<lower]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data["width"]>upper]
# Out:
#     symboling  normalized_losses           make fuel_type aspiration  \
# 64         -1               93.0  mercedes-benz    diesel      turbo
# 65         -1               93.0  mercedes-benz    diesel      turbo
# 66          0               93.0  mercedes-benz    diesel      turbo
#
#    num_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 64         four      sedan          rwd           front       110.0  ...
# 65         four      wagon          rwd           front       110.0  ...
# 66          two    hardtop          rwd           front       106.7  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 64          183          idi  3.58    3.64              21.5      123.0
# 65          183          idi  3.58    3.64              21.5      123.0
# 66          183          idi  3.58    3.64              21.5      123.0
#
#     peak_rpm city_mpg  highway_mpg  price
# 64    4350.0       22           25  25552
# ...

# %%
(len(data.loc[data["width"]<lower])+len(data.loc[data["width"]>upper]))/len(data)*100
# Out:
# 1.4925373134328357

# %%
data.loc[data["width"]<lower,"width"] = data["width"].median()

# %%
data.loc[data["width"]<lower]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data["width"]>upper,"width"] = data["width"].median()

# %%
data.loc[data["width"]>upper]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
sns.boxplot(x=data["width"])
# Out:
# <Axes: xlabel='width'>

# %%
## curb_weight
q1=data["curb_weight"].quantile(0.25)
q1
# Out:
# 2169.0

# %%
q3=data["curb_weight"].quantile(0.75)
q3
# Out:
# 2912.0

# %%
iqr = q3-q1
iqr
# Out:
# 743.0

# %%
lower= q1-1.5*iqr
lower
# Out:
# 1054.5

# %%
upper= q3+1.5*iqr
upper
# Out:
# 4026.5

# %%
data.loc[data["curb_weight"]<lower]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data["curb_weight"]>upper]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
sns.boxplot(x=data["curb_weight"])
# Out:
# <Axes: xlabel='curb_weight'>

# %%
data.loc[data["curb_weight"]>upper, "curb_weight"] = data["curb_weight"].median()

# %%
data.loc[data["curb_weight"]>upper]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
# engine_size
q1= data["engine_size"].quantile(0.25)
q1
# Out:
# 98.0

# %%
q3= data["engine_size"].quantile(0.75)
q3
# Out:
# 136.0

# %%
iqr=q3-q1
iqr
# Out:
# 38.0

# %%
lower = q1-1.5*iqr
lower
# Out:
# 41.0

# %%
upper = q3+1.5*iqr
upper
# Out:
# 193.0

# %%
data.loc[data["engine_size"]<lower]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data["engine_size"]>upper]
# Out:
#      symboling  normalized_losses     make fuel_type aspiration num_of_doors  \
# 123          3              115.0  porsche       gas        std          two
# 124          3              115.0  porsche       gas        std          two
# 125          3              115.0  porsche       gas        std          two
#
#       body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 123      hardtop          rwd            rear        89.5  ...          194
# 124      hardtop          rwd            rear        89.5  ...          194
# 125  convertible          rwd            rear        89.5  ...          194
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 123         mpfi  3.74     2.9               9.5      207.0    5900.0
# 124         mpfi  3.74     2.9               9.5      207.0    5900.0
# 125         mpfi  3.74     2.9               9.5      207.0    5900.0
#
#     city_mpg  highway_mpg  price
# ...

# %%
len(data.loc[data["engine_size"]>upper])/len(data)*100
# Out:
# 1.4925373134328357

# %%
data.loc[data["engine_size"]>upper, "engine_size"]= data["engine_size"].median()

# %%
data.loc[data["engine_size"]>upper]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
sns.boxplot(x=data["engine_size"])
# Out:
# <Axes: xlabel='engine_size'>

# %%
# stroke
q1= data["stroke"].quantile(0.25)
q1
# Out:
# 3.19

# %%
q3 = data["stroke"].quantile(0.75)
q3
# Out:
# 3.4

# %%
iqr=q3-q1
iqr
# Out:
# 0.20999999999999996

# %%
lower= q1-1.5*iqr
lower
# Out:
# 2.875

# %%
upper = q3+1.5*iqr
upper
# Out:
# 3.715

# %%
data.loc[data["stroke"]<lower]
# Out:
#      symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 9            2              115.0    bmw       gas        std          two
# 10           0              115.0    bmw       gas        std         four
# 198         -1               95.0  volvo       gas        std         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 9        sedan          rwd           front       101.2  ...          108
# 10       sedan          rwd           front       101.2  ...          108
# 198      sedan          rwd           front       109.1  ...          173
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 9           mpfi  3.50    2.80               8.8      101.0    5800.0
# 10          mpfi  3.50    2.80               8.8      101.0    5800.0
# 198         mpfi  3.58    2.87               8.8      134.0    5500.0
#
#     city_mpg  highway_mpg  price
# 9         23           29  16430
# ...

# %%
data.loc[data["stroke"]>upper]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data["stroke"]<lower, "stroke"] = data["stroke"].median()

# %%
data.loc[data["stroke"]>upper, "stroke"] = data["stroke"].median()

# %%
data.loc[data["stroke"]>upper]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
sns.boxplot(x=data["stroke"])
# Out:
# <Axes: xlabel='stroke'>

# %%
# compression_ratio
q1= data["compression_ratio"].quantile(0.25)
q1
# Out:
# 8.6

# %%
q3=data["compression_ratio"].quantile(0.75)
q3
# Out:
# 9.4

# %%
iqr = q3-q1
iqr
# Out:
# 0.8000000000000007

# %%
lower = q1-1.5*iqr
lower
# Out:
# 7.399999999999999

# %%
upper = q3+1.5*iqr
upper
# Out:
# 10.600000000000001

# %%
data.loc[data["compression_ratio"]<lower]
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 28           3              145.0       dodge       gas      turbo
# 79           3              115.0  mitsubishi       gas      turbo
# 80           3              115.0  mitsubishi       gas      turbo
# 81           3              115.0  mitsubishi       gas      turbo
# 114          0              161.0      peugot       gas      turbo
# 121          3              115.0    plymouth       gas      turbo
#
#     num_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 28           two  hatchback          fwd           front        95.9  ...
# 79           two  hatchback          fwd           front        95.9  ...
# 80           two  hatchback          fwd           front        95.9  ...
# 81           two  hatchback          fwd           front        95.9  ...
# 114         four      sedan          rwd           front       108.0  ...
# ...

# %%
data.loc[data["compression_ratio"]>upper]
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 46           0              115.0         jaguar       gas        std
# 60           0              115.0          mazda    diesel        std
# 63           0              115.0          mazda    diesel        std
# 64          -1               93.0  mercedes-benz    diesel      turbo
# 65          -1               93.0  mercedes-benz    diesel      turbo
# 66           0               93.0  mercedes-benz    diesel      turbo
# 67          -1               93.0  mercedes-benz    diesel      turbo
# 87           1              128.0         nissan    diesel        std
# 105          0              161.0         peugot    diesel      turbo
# 107          0              115.0         peugot    diesel      turbo
# 109          0              161.0         peugot    diesel      turbo
# 111          0              115.0         peugot    diesel      turbo
# ...

# %%
len(data.loc[data["compression_ratio"]<lower])
# Out:
# 6

# %%
len(data.loc[data["compression_ratio"]>upper])
# Out:
# 21

# %%
(len(data.loc[data["compression_ratio"]<lower])+len(data.loc[data["compression_ratio"]>upper]))/len(data)*100

# since the percntage of outlier for the data of "compression_ratio" is higher than 8%. we are not handling the outlier.
# Out:
# 13.432835820895523

# %%
# horsepower
q1= data["horsepower"].quantile(0.25)
q1
# Out:
# 70.0

# %%
q3= data["horsepower"].quantile(0.75)
q3
# Out:
# 116.0

# %%
iqr= q3-q1
iqr
# Out:
# 46.0

# %%
lower = q1-1.5*iqr
lower
# Out:
# 1.0

# %%
upper = q3+1.5*iqr
upper
# Out:
# 185.0

# %%
data.loc[data["horsepower"]<lower]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data["horsepower"]>upper]
# Out:
#      symboling  normalized_losses     make fuel_type aspiration num_of_doors  \
# 46           0              115.0   jaguar       gas        std          two
# 102          3              115.0   nissan       gas      turbo          two
# 123          3              115.0  porsche       gas        std          two
# 124          3              115.0  porsche       gas        std          two
# 125          3              115.0  porsche       gas        std          two
#
#       body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 46         sedan          rwd           front       102.0  ...          120
# 102    hatchback          rwd           front        91.3  ...          181
# 123      hardtop          rwd            rear        89.5  ...          120
# 124      hardtop          rwd            rear        89.5  ...          120
# 125  convertible          rwd            rear        89.5  ...          120
#
# ...

# %%
data.loc[data["horsepower"]>upper, "horsepower"] = data["horsepower"].median()

# %%
data.loc[data["horsepower"]>upper]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
sns.boxplot(x=data["horsepower"])
# Out:
# <Axes: xlabel='horsepower'>

# %%
# peak_rpm
q1 = data["peak_rpm"].quantile(0.25)
q1
# Out:
# 4800.0

# %%
q3 = data["peak_rpm"].quantile(0.75)
q3
# Out:
# 5500.0

# %%
iqr = q3-q1
iqr
# Out:
# 700.0

# %%
lower = q1-1.5*iqr
lower
# Out:
# 3750.0

# %%
upper = q3+1.5*iqr
upper
# Out:
# 6550.0

# %%
data.loc[data["peak_rpm"]<lower]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data["peak_rpm"]>upper]
# Out:
#      symboling  normalized_losses    make fuel_type aspiration num_of_doors  \
# 161          1              168.0  toyota       gas        std          two
# 162          1              168.0  toyota       gas        std          two
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 161      sedan          rwd           front        94.5  ...           98
# 162  hatchback          rwd           front        94.5  ...           98
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 161         mpfi  3.24    3.08               9.4      112.0    6600.0
# 162         mpfi  3.24    3.08               9.4      112.0    6600.0
#
#     city_mpg  highway_mpg  price
# 161       26           29   9298
# 162       26           29   9538
#
# [2 rows x 26 columns]

# %%
data.loc[data["peak_rpm"]>upper, "peak_rpm"] = data["peak_rpm"].median()

# %%
data.loc[data["peak_rpm"]>upper]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
sns.boxplot(x=data["peak_rpm"])
# Out:
# <Axes: xlabel='peak_rpm'>

# %%
# city_mpg
q1= data["city_mpg"].quantile(0.25)
q1
# Out:
# 19.0

# %%
q3 = data["city_mpg"].quantile(0.75)
q3
# Out:
# 30.0

# %%
iqr = q3-q1
iqr
# Out:
# 11.0

# %%
lower = q1-1.5*iqr
lower
# Out:
# 2.5

# %%
upper = q3+1.5*iqr
upper
# Out:
# 46.5

# %%
data.loc[data["city_mpg"]<lower]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data["city_mpg"]>upper]
# Out:
#     symboling  normalized_losses       make fuel_type aspiration num_of_doors  \
# 17          2              121.0  chevrolet       gas        std          two
# 29          2              137.0      honda       gas        std          two
#
#    body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 17  hatchback          fwd           front        88.4  ...           61
# 29  hatchback          fwd           front        86.6  ...           92
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 17         2bbl  2.91    3.03               9.5       48.0    5100.0       47
# 29         1bbl  2.91    3.41               9.6       58.0    4800.0       49
#
#     highway_mpg  price
# 17           53   5151
# 29           54   6479
#
# [2 rows x 26 columns]

# %%
len(data.loc[data["city_mpg"]>upper])
# Out:
# 2

# %%
data.loc[data["city_mpg"]>upper, "city_mpg"] = data["city_mpg"].median()

# %%
data.loc[data["city_mpg"]>upper]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
# highway_mpg
q1 = data["highway_mpg"].quantile(0.25)
q1
# Out:
# 25.0

# %%
q3 = data["highway_mpg"].quantile(0.75)
q3
# Out:
# 34.0

# %%
iqr = q3-q1
iqr
# Out:
# 9.0

# %%
lower = q1-1.5*iqr
lower
# Out:
# 11.5

# %%
upper = q3+1.5*iqr
upper
# Out:
# 47.5

# %%
data.loc[data["highway_mpg"]<lower]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.loc[data["highway_mpg"]>upper]
# Out:
#     symboling  normalized_losses       make fuel_type aspiration num_of_doors  \
# 17          2              121.0  chevrolet       gas        std          two
# 29          2              137.0      honda       gas        std          two
# 87          1              128.0     nissan    diesel        std          two
#
#    body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 17  hatchback          fwd           front        88.4  ...           61
# 29  hatchback          fwd           front        86.6  ...           92
# 87      sedan          fwd           front        94.5  ...          103
#
#     fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# 17         2bbl  2.91    3.03               9.5       48.0    5100.0       24
# 29         1bbl  2.91    3.41               9.6       58.0    4800.0       24
# 87          idi  2.99    3.47              21.9       55.0    4800.0       45
#
#     highway_mpg  price
# ...

# %%
data.loc[data["highway_mpg"]>upper, "highway_mpg"] = data["highway_mpg"].median()

# %%
data.loc[data["highway_mpg"]>upper]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
sns.boxplot(x=data["highway_mpg"])
# Out:
# <Axes: xlabel='highway_mpg'>

# %%
sns.pairplot(data)

# %%
plot=1
plt.figure(figsize=(12,40))
for i in data.select_dtypes(include='number').drop('price',axis=1):
    if plot<=16:
        ax=plt.subplot(8,2,plot)
        sns.boxplot(x=data[i])
        plt.xlabel(i)
    plot+=1
plt.tight_layout()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized_losses  201 non-null    float64
#  2   make               201 non-null    object
#  3   fuel_type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num_of_doors       201 non-null    object
#  6   body_style         201 non-null    object
#  7   drive_wheels       201 non-null    object
#  8   engine_location    201 non-null    object
#  9   wheel_base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb_weight        201 non-null    int64
#  14  engine_type        201 non-null    object
#  15  num_of_cylinders   201 non-null    object
# ...

# %%
data['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinal_en=OrdinalEncoder(categories=[['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
       'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
       'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
       'saab', 'subaru', 'toyota', 'volkswagen', 'volvo']])

# %%
ordinal_en
# Out:
# OrdinalEncoder(categories=[['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge',
#                             'honda', 'isuzu', 'jaguar', 'mazda',
#                             'mercedes-benz', 'mercury', 'mitsubishi', 'nissan',
#                             'peugot', 'plymouth', 'porsche', 'renault', 'saab',
#                             'subaru', 'toyota', 'volkswagen', 'volvo']])

# %%
data['make']=ordinal_en.fit_transform(data[['make']])

# %%
data
# Out:
#      symboling  normalized_losses  make fuel_type aspiration num_of_doors  \
# 0            3              115.0   0.0       gas        std          two
# 1            3              115.0   0.0       gas        std          two
# 2            1              115.0   0.0       gas        std          two
# 3            2              164.0   1.0       gas        std         four
# 4            2              164.0   1.0       gas        std         four
# ..         ...                ...   ...       ...        ...          ...
# 196         -1               95.0  21.0       gas        std         four
# 197         -1               95.0  21.0       gas      turbo         four
# 198         -1               95.0  21.0       gas        std         four
# 199         -1               95.0  21.0    diesel      turbo         four
# 200         -1               95.0  21.0       gas      turbo         four
#
#       body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# ...

# %%
data['fuel_type'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
pd.get_dummies(data['fuel_type'],dtype='int',drop_first=True)
# Out:
#      gas
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ..   ...
# 196    1
# 197    1
# 198    1
# 199    0
# 200    1
#
# [201 rows x 1 columns]

# %%
data=pd.get_dummies(data,columns=['fuel_type'],dtype='int',drop_first=True)

# %%
data['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
pd.get_dummies(data['aspiration'],dtype='int',drop_first=True)
# Out:
#      turbo
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 196      0
# 197      1
# 198      0
# 199      1
# 200      1
#
# [201 rows x 1 columns]

# %%
data=pd.get_dummies(data,columns=['aspiration'],dtype='int',drop_first=True)

# %%
data['num_of_doors'].unique()
# Out:
# array(['two', 'four', '?'], dtype=object)

# %%
data['num_of_doors'].value_counts()
# Out:
# num_of_doors
# four    115
# two      86
# Name: count, dtype: int64

# %%
data.loc[data['num_of_doors']=='?','num_of_doors'] = data['num_of_doors'].mode()[0]

# %%
nod_map={
    'two':2,
    'four':4}
data['num_of_doors']=data['num_of_doors'].map(nod_map)

# %%
data['body_style'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
data['body_style'].value_counts()
# Out:
# body_style
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
data.loc[data['body_style']=='four', 'body_style'] = data['body_style'].mode()[0]

# %%
# encoding - Lable 

data['body_style'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
ordinal_=OrdinalEncoder(categories=[['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop']])

# %%
ordinal_
# Out:
# OrdinalEncoder(categories=[['convertible', 'hatchback', 'sedan', 'wagon',
#                             'hardtop']])

# %%
data['body_style']= ordinal_.fit_transform(data[['body_style']])

# %%
data['drive_wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
data['drive_wheels'].value_counts()
# Out:
# drive_wheels
# fwd    118
# rwd     75
# 4wd      8
# Name: count, dtype: int64

# %%
oe = OrdinalEncoder(categories = [['rwd', 'fwd', '4wd']])
oe
# Out:
# OrdinalEncoder(categories=[['rwd', 'fwd', '4wd']])

# %%
data['drive_wheels']=oe.fit_transform(data[['drive_wheels']])

# %%
data['engine_location'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
ord=OrdinalEncoder(categories=[['front', 'rear']])
ord
# Out:
# OrdinalEncoder(categories=[['front', 'rear']])

# %%
data['engine_location']=ord.fit_transform(data[['engine_location']])

# %%
data['engine_type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf'], dtype=object)

# %%
data.loc[data['engine_type']=='l','engine_type']=data['engine_type'].mode()[0]

# %%
data['engine_type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'rotor', 'ohcf'], dtype=object)

# %%
orr=OrdinalEncoder(categories=[['dohc', 'ohcv', 'ohc', 'rotor', 'ohcf']])
orr
# Out:
# OrdinalEncoder(categories=[['dohc', 'ohcv', 'ohc', 'rotor', 'ohcf']])

# %%
data['engine_type']=orr.fit_transform(data[['engine_type']])

# %%
data['num_of_cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
noc_mapping = {
    'two': 2,
    'three': 3,
    'four': 4,
    'five': 5,
    'six': 6,
    'eight': 8,
    'twelve': 12
}
data['num_of_cylinders'] = data['num_of_cylinders'].map(noc_mapping)

# %%
data['fuel_system'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
data=pd.get_dummies(data,columns=['fuel_system'],dtype='int',drop_first=True)

# %%
data
# Out:
#      symboling  normalized_losses  make  num_of_doors  body_style  \
# 0            3              115.0   0.0             2         0.0
# 1            3              115.0   0.0             2         0.0
# 2            1              115.0   0.0             2         1.0
# 3            2              164.0   1.0             4         2.0
# 4            2              164.0   1.0             4         2.0
# ..         ...                ...   ...           ...         ...
# 196         -1               95.0  21.0             4         2.0
# 197         -1               95.0  21.0             4         2.0
# 198         -1               95.0  21.0             4         2.0
# 199         -1               95.0  21.0             4         2.0
# 200         -1               95.0  21.0             4         2.0
#
#      drive_wheels  engine_location  wheel_base  length  width  ...  price  \
# 0             0.0              0.0        88.6   168.8   64.1  ...  13495
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized_losses  201 non-null    float64
#  2   make               201 non-null    float64
#  3   num_of_doors       201 non-null    int64
#  4   body_style         201 non-null    float64
#  5   drive_wheels       201 non-null    float64
#  6   engine_location    201 non-null    float64
#  7   wheel_base         201 non-null    float64
#  8   length             201 non-null    float64
#  9   width              201 non-null    float64
#  10  height             201 non-null    float64
#  11  curb_weight        201 non-null    int64
#  12  engine_type        201 non-null    float64
#  13  num_of_cylinders   201 non-null    int64
#  14  engine_size        201 non-null    int64
#  15  bore               201 non-null    float64
# ...

# %%
x=data.drop(columns='price',axis=1)
y=data['price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train.shape
# Out:
# (160, 31)

# %%
x_test.shape
# Out:
# (41, 31)

# %%
y_train.shape
# Out:
# (160,)

# %%
y_test.shape
# Out:
# (41,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([ 4761.2076538 , 32120.43614375,  4270.52267355,  6884.31378749,
#        15557.80323483,  4363.39347348, 35727.50700839, 10632.58265138,
#        21317.6632748 , 28238.83553674, 19038.79422161, 11139.9725566 ,
#        12437.41231758, 10646.04191353, 12276.5730757 ,  9035.55652803,
#        10796.21026975,  6528.94072927,  9130.35823014, 33990.06096974,
#        32528.        , 34706.02522358,  6799.59630442,  6304.73226806,
#        20919.80286443, 11140.05738945, 10423.5915735 , 19632.66885192,
#        34985.58343632, 18542.51852584, 17476.35152763,  6834.99281132,
#        15630.36670708,  5761.65855663,  4908.87204465, 17773.66241458,
#         9013.51861625,  8730.20892945, 10644.87466817,  6475.20049359,
#        13357.84295438])

# %%
y_test
# Out:
# 95      8249
# 15     41315
# 30      6855
# 158     9258
# 128    11850
# 115     5572
# 69     35056
# 171     9988
# 175    15998
# 45     35550
# 66     28176
# 183     9495
# 165     9989
# 78      8499
# 187    13295
# 178     7775
# 56      8845
# 152     6938
# 82      6989
# 68     34184
# 124    34028
# 16     36880
# 148     6488
# 93      7499
# 65     28248
# 60     10795
# 84      9279
# 67     31600
# 125    37028
# 132    18150
# 9      16430
# 18      6295
# 55     15645
# 75      6669
# 150     7898
# 104    11900
# 135     7053
# 137     7126
# 164     9639
# 76      7689
# 79     12629
# Name: price, dtype: int64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mse=mean_squared_error(y_pred,y_test)
mse
# Out:
# 14173661.120025055

# %%
mar=np.sqrt(mse)
mar
# Out:
# 3764.792307687777

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8841517372064591

# %%
sample=pd.DataFrame([[2	,94.0,	20.0	,1.0	,2.0,	1.0	,0.0	,97.3	,171.7,	65.5,	55.7,	2264,	2.0,	4	,97,	3.01,	3.40,	23.00,	52.0,	4800.0,	37,	46,		0,	0	,0,	0,1,	0,	0,	0,	0]],columns=x.columns)
lr.predict(sample)
# Out:
# array([1040674.82552477])

# %%
#sample = pd.DataFrame([[...]], columns=x.columns)
#lr.predict(sample)

# %%
sns.boxplot(x=data['price'])
# Out:
# <Axes: xlabel='price'>

# %%
data
# Out:
#      symboling  normalized_losses  make  num_of_doors  body_style  \
# 0            3              115.0   0.0             2         0.0
# 1            3              115.0   0.0             2         0.0
# 2            1              115.0   0.0             2         1.0
# 3            2              164.0   1.0             4         2.0
# 4            2              164.0   1.0             4         2.0
# ..         ...                ...   ...           ...         ...
# 196         -1               95.0  21.0             4         2.0
# 197         -1               95.0  21.0             4         2.0
# 198         -1               95.0  21.0             4         2.0
# 199         -1               95.0  21.0             4         2.0
# 200         -1               95.0  21.0             4         2.0
#
#      drive_wheels  engine_location  wheel_base  length  width  ...  price  \
# 0             0.0              0.0        88.6   168.8   64.1  ...  13495
# ...

# %%
7995
